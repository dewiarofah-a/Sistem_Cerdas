# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
P = [2, 4, 4, 4, 5, 5, 7, 9]
Q = [10, 13, 15, 14, 13, 16, 18, 21]
x = [1, 2, 3, 4, 5, 6, 7, 8]

# %%
plt.scatter(x,P,color='g', marker='D')
plt.scatter(x,Q,color='r', marker='s')
plt.title('Korelasi antara P dan Q')
plt.xlabel('Range')
plt.ylabel('Value')
plt.legend((P, Q), loc= 'upper left')
plt.show()
